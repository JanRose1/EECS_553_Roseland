# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# These flags determine which data to load
noisy_data = 0
clean_landmark = 0

base_path = os.getcwd()

# Load results
data_type = 'noisy_data' if noisy_data else 'clean_data'
#variants = ('beta0.3', 'beta0.4', 'beta0.5')
variants = ('pca', 'beta0.3', 'beta0.4', 'beta0.5')
acc_data = {}

for variant in variants:
    current_path = os.path.join(base_path, 'new_dataset', 'beta0.3')

    os.chdir(current_path)

    if 'beta' in variant:
        acc_data['acc_nys_' + variant[-3:]] = np.mean(np.load('list_datanys.pkl', allow_pickle = True), axis=0)
        acc_data['acc_roseland_' + variant[-3:]] = np.mean(np.load('list_data.pkl', allow_pickle = True), axis=0)
    else:
        acc_data['acc_' + variant] = np.load('acc_pca.npy')
        #acc_data['acc_' + variant] = np.load('acc_{}.npy'.format(variant.split('.')[0]))

# Plotting
def plot_accuracy(embed_dim, title_suffix, yticks, beta_suffix):
    
    dim = np.arange(2, embed_dim + 1, 3)
    plt.figure(figsize=(12, 7))
    #plt.plot(dim, acc_data['acc_pca'][dim - 1], '--*', markersize=10, linewidth=3, label='PCA')
    # plt.plot(dim, acc_data['acc_dm'][dim - 1], '--o', markersize=10, linewidth=3, label='DM')
    plt.plot(dim, acc_data['acc_roseland_' + beta_suffix][dim - 1], '--s', markersize=10, linewidth=3, label='Roseland')
    plt.plot(dim, acc_data['acc_nys_' + beta_suffix][dim - 1], '--^', markersize=10, linewidth=3, label='Nystrom')
    if 'acc_LLL_' + beta_suffix in acc_data:
        plt.plot(dim, acc_data['acc_LLL_' + beta_suffix][dim - 1], '--+', markersize=10, linewidth=3, label='LLL')

    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.yticks(yticks)
    plt.xticks(dim)
    plt.gca().set_axisbelow(True)
    plt.gca().tick_params(axis='both', labelsize=12)
    plt.xlabel('Embedding dimension', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.legend(fontsize=12)
    # plt.tight_layout()
    plt.title('MMASH Error (' + title_suffix + ')', fontsize=18)
    plt.show()

# For each beta setting, plot the accuracy

plot_accuracy(27, 'beta=0.3', np.arange(0.1, 0.8, 0.1), '0.3')
plot_accuracy(50, 'beta=0.4', np.arange(0.1, 0.8, 0.1), '0.4')
plot_accuracy(50, 'beta=0.5', np.arange(0.1, 0.8, 0.1), '0.5')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_491128/3323377843.py in <module>
#      24         acc_data['acc_roseland_' + variant[-3:]] = np.mean(np.load('list_data.pkl', allow_pickle = True), axis=0)
#      25     else:
# ---> 26         acc_data['acc_' + variant] = np.load('acc_pca.npy')
#      27         #acc_data['acc_' + variant] = np.load('acc_{}.npy'.format(variant.split('.')[0]))
#      28
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'acc_pca.npy'

# %%
#beta 0.3
import os
import numpy as np
import matplotlib.pyplot as plt

current_path = os.path.join(base_path, 'new_dataset', 'beta0.3')
os.chdir(current_path)
acc_data_nys_3 = np.mean(np.load('acc_nys_physio.npy'), axis=0)
acc_data_rose_3 = np.mean(np.load('acc_roseland_physio.npy'), axis=0)
os.chdir(os.path.join(os.getcwd(),'../../clean_data/pca'))
acc_data_pca = np.load('acc_pca.npy')

beta_suffix = '0.3'
yticks = np.arange(0.1, 0.8, 0.1)
title_suffix = 'beta=0.3'

dim = np.arange(2, 7 + 1, 1)
plt.figure(figsize=(12, 7))
#plt.plot(dim, acc_data['acc_pca'][dim - 1], '--*', markersize=10, linewidth=3, label='PCA')
plt.plot(dim, acc_data_pca[dim - 1], '--*', markersize=10, linewidth=3, label='PCA')
# plt.plot(dim, acc_data['acc_dm'][dim - 1], '--o', markersize=10, linewidth=3, label='DM')
plt.plot(dim, acc_data_rose_3[dim - 1], '--s', markersize=10, linewidth=3, label='Roseland')
plt.plot(dim, acc_data_nys_3[dim - 1], '--^', markersize=10, linewidth=3, label='Nystrom')


plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.yticks(yticks)
plt.xticks(dim)
plt.gca().set_axisbelow(True)
plt.gca().tick_params(axis='both', labelsize=12)
plt.xlabel('Embedding dimension', fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.legend(fontsize=12)
# plt.tight_layout()
plt.title('MMASH Error (' + title_suffix + ')', fontsize=18)
plt.show()

# %%
#beta 0.4
import os
import numpy as np
import matplotlib.pyplot as plt

current_path = os.path.join(base_path, 'new_dataset', 'beta0.4')
os.chdir(current_path)
acc_data_nys_4 = np.mean(np.load('acc_nys_physio.npy'), axis=0)
acc_data_rose_4 = np.mean(np.load('acc_roseland_physio.npy'), axis=0)
os.chdir(os.path.join(os.getcwd(),'../../clean_data/pca'))
acc_data_pca = np.load('acc_pca.npy')

beta_suffix = '0.4'
yticks = np.arange(0.1, 0.8, 0.1)
title_suffix = 'beta=0.4'

dim = np.arange(2, 7 + 1, 1)
plt.figure(figsize=(12, 7))
#plt.plot(dim, acc_data['acc_pca'][dim - 1], '--*', markersize=10, linewidth=3, label='PCA')
plt.plot(dim, acc_data_pca[dim - 1], '--*', markersize=10, linewidth=3, label='PCA')
# plt.plot(dim, acc_data['acc_dm'][dim - 1], '--o', markersize=10, linewidth=3, label='DM')
plt.plot(dim, acc_data_rose_4[dim - 1], '--s', markersize=10, linewidth=3, label='Roseland')
plt.plot(dim, acc_data_nys_4[dim - 1], '--^', markersize=10, linewidth=3, label='Nystrom')


plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.yticks(yticks)
plt.xticks(dim)
plt.gca().set_axisbelow(True)
plt.gca().tick_params(axis='both', labelsize=12)
plt.xlabel('Embedding dimension', fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.legend(fontsize=12)
# plt.tight_layout()
plt.title('MMASH Error (' + title_suffix + ')', fontsize=18)
plt.show()

# %%
# Out:
# array([0.25898779, 0.26389421, 0.26712893, 0.29417664, 0.28906674,
#        0.28878094, 0.28864256])

# %%
#beta 0.5
import os
import numpy as np
import matplotlib.pyplot as plt

current_path = os.path.join(base_path, 'new_dataset', 'beta0.5')
os.chdir(current_path)
acc_data_nys_5 = np.mean(np.load('acc_nys_physio.npy'), axis=0)
acc_data_rose_5 = np.mean(np.load('acc_roseland_physio.npy'), axis=0)

os.chdir(os.path.join(os.getcwd(),'../../clean_data/pca'))
acc_data_pca = np.load('acc_pca.npy')

beta_suffix = '0.5'
yticks = np.arange(0.1, 0.8, 0.1)
title_suffix = 'beta=0.5'

dim = np.arange(2, 7 + 1, 1)
plt.figure(figsize=(12, 7))
plt.plot(dim, acc_data_pca[dim - 1], '--*', markersize=10, linewidth=3, label='PCA')
# plt.plot(dim, acc_data['acc_dm'][dim - 1], '--o', markersize=10, linewidth=3, label='DM')
plt.plot(dim, acc_data_rose_5[dim - 1], '--s', markersize=10, linewidth=3, label='Roseland')
plt.plot(dim, acc_data_nys_5[dim - 1], '--^', markersize=10, linewidth=3, label='Nystrom')


plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.yticks(yticks)
plt.xticks(dim)
plt.gca().set_axisbelow(True)
plt.gca().tick_params(axis='both', labelsize=12)
plt.xlabel('Embedding dimension', fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.legend(fontsize=12)
# plt.tight_layout()
plt.title('MMASH Error (' + title_suffix + ')', fontsize=18)
plt.show()

# %%
# Out:
# /home/janrose/EECS553/Project/eecs553_Roseland-main/clean_data/pca

# %%
#os.chdir('Project')
# os.chdir('eecs553_Roseland-main')
# base_path = os.getcwd()
# current_path = os.path.join(base_path, 'new_dataset', 'beta0.3')
# os.chdir(current_path)
#0.3
time_nys = np.load('time_nys_physio.npy')
mean_time_nys = np.mean(time_nys)
std_nys = np.std(time_nys)

time_rose = np.load('time_roseland_physio.npy')
mean_rose = np.mean(time_rose)
std_rose = np.std(time_rose)

# %%
print(mean_time_nys)
print(std_nys)
print(mean_rose)
print(std_rose)
# Out:
# 0.07031513849894205
# 0.006503377758549534
# 0.279052734375
# 0.017226028062503347

# %%
os.chdir('beta0.3')
print(os.getcwd())
# Out:
# /home/janrose/EECS553/Project/eecs553_Roseland-main/new_dataset/beta0.3

# %%
#beta = 0.4
os.chdir('../')
os.chdir('beta0.4')
time_nys = np.load('time_nys_physio.npy')
mean_time_nys = np.mean(time_nys)
std_nys = np.std(time_nys)

time_rose = np.load('time_roseland_physio.npy')
mean_rose = np.mean(time_rose)
std_rose = np.std(time_rose)
print(mean_time_nys)
print(std_nys)
print(mean_rose)
print(std_rose)
# Out:
# 0.305796480178833
# 0.006476456683420082
# 1.9067206541697184
# 0.12192328632077364

# %%
#beta = 0.4
os.chdir('../')
os.chdir('beta0.5')
time_nys = np.load('time_nys_physio.npy')
mean_time_nys = np.mean(time_nys)
std_nys = np.std(time_nys)

time_rose = np.load('time_roseland_physio.npy')
mean_rose = np.mean(time_rose)
std_rose = np.std(time_rose)
print(mean_time_nys)
print(std_nys)
print(mean_rose)
print(std_rose)
# Out:
# 1.0902064323425293
# 0.01008164397213884
# 5.524531157811483
# 0.20697910378494455

# %%
#os.chdir('../..')
# os.chdir('clean_data')
# os.chdir('pca')
# print(os.getcwd())

time_pca = np.load('time_pca.npy')
print(time_pca)
# print(np.mean(time_pca))
# print(np.std(time_pca))
# Out:
# 0.023104429244995117
